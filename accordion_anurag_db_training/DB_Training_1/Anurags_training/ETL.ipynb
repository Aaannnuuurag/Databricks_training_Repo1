# %%
df_f_dataset=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)

# %%
df_f_dataset.display()

# %%
df_f_dataset.select("CustomerId").display()

# %%
df_f_dataset.withColumnsRenamed({"CustomerID":"cust_id",})

# %%
df_f_dataset=df_f_dataset.withColumnsRenamed({"CustomerID":"customer_id","TransactionID":"transaction_id"})

# %%
df_f_dataset.display()

# %%
from pyspark.sql.functions import *

# %%
df_f_dataset.withColumn("ingestion_date",current_timestamp()).display()
