# %%
# %sql
-- grant use schema on schema acc_dev.anurag_bronze to `vijayboggavarapu8@gmail.com`;
grant select on table  acc_dev.anurag_bronze.housing to `vijayboggavarapu8@gmail.com`;
-- GRANT SELECT ON TABLE acc_dev.anurag_bronze.housing TO `vijayboggavarapu8@gmail.com`;

# %%
revoke privilege on object object_name from name;

# %%
# %sql
revoke select on table acc_dev.anurag_bronze.housing from vija;
