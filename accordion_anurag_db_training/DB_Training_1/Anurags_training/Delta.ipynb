# %%
# %sql
use catalog acc_dev;
use schema anurag;

# %%
# %sql
create table if not exists emp(id int, name string, city string)

# %%
# %sql
-- insert into emp values (1,'Naval','Solapur')
insert into emp values (1,'anurag','Hyd')

# %%
# %sql
-- select * from emp;
-- desc extended emp;
desc history emp;
-- desc detail emp;

# %% [markdown]
# Time Travel

# %%
# %sql
-- select * from emp version as of 0;
select * from emp timestamp as of '2025-11-05T05:09:38.000+00:00'

# %%
# %sql
insert into emp values (100,'abhi','bus')

# %% [markdown]
# Restore

# %%
# %sql 
restore table emp to version as of 2
