# %%
# %run "/Workspace/Users/anuragrayabharapu@gmail.com/multi hop clone/includes"

# %%
# %sql
select *  from acc_dev.anurag_bronze.sales;

# %%
# reader
df=spark.table(f"{catalog}.{schema}.sales")
df.display()
#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.anurag_silver.sales_cleaned")

# %%
# %sql
--select * from acc_dev.anurag_bronze.sales
select distinct * from acc_dev.anurag_bronze.sales where order_id is not null
